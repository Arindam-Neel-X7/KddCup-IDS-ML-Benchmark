# %% [markdown]
# <a href="https://colab.research.google.com/github/Arindam-Neel-X7/KddCup-IDS-ML-Benchmark/blob/main/Notebooks/ADA_Boost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
df = pd.read_csv('/content/drive/MyDrive/KddCup/data/kdd_clean.csv')

df.head()

# %%
df = pd.get_dummies(df, columns=['protocol_type', 'service', 'flag'])

# %%
X = df.drop('label', axis=1)
y = df['label']

# %%
def run_adaboost(test_size):

    print(f"===== TEST SIZE: {test_size} =====\n")

    # Split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=test_size,
        random_state=42,
        stratify=y
    )

    # Scaling (optional, but keeping consistent)
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)

    # PCA
    pca = PCA(n_components=10)
    X_train = pca.fit_transform(X_train)
    X_test = pca.transform(X_test)

    # Base learner (decision stump)
    base_model = DecisionTreeClassifier(max_depth=1)

    # AdaBoost model
    model = AdaBoostClassifier(
        estimator=base_model,
        n_estimators=100,
        learning_rate=0.5,
        random_state=42
    )

    model.fit(X_train, y_train)

    # Prediction
    y_pred = model.predict(X_test)

    # Evaluation
    print("Accuracy:", accuracy_score(y_test, y_pred))

    print("\nClassification Report:\n")
    print(classification_report(y_test, y_pred))

    print("\nConfusion Matrix:\n")
    print(confusion_matrix(y_test, y_pred))
    print("\n")

    # Plot
    ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
    plt.title(f"AdaBoost (Test Size = {test_size})")
    plt.show()

# %% [markdown]
# **ADA with 80,20**

# %%
run_adaboost(0.2)

# %% [markdown]
# **ADA with 60,40**

# %%
run_adaboost(0.4)

# %% [markdown]
# **ADA with 40,60**

# %%
run_adaboost(0.6)
